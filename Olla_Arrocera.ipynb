# %%
#INSTRUCCIONES
#Ingrese las ubicaciones COCINA1/COCINA2/COCINA3 con letras mayusculas
#Ingrese el estado 0/1 respectivamente donde 0 significa cocinar y 1 significa calentar

def Olla_Arrocera():
    # inicializamos estadoObjetivo
    # 0 idica Cocinando y 1 indica calentando
    estadoObjetivo = {'COCINA1': '0', 'COCINA2': '0', 'COCINA3': '0'}
    costo = 0
    
    ubicacion = input("Ingrese la ubicación de la Olla Arrocera: ")# el usuario indica la ubicación de la olla arrocera
    estado = input("Ingrese el estado del: "+ubicacion+ " ")# el usuario indica la si la olla arrocera se encuentra Calentando o Cocinando (0/1) en la ubicación indicada.
    
    if (ubicacion  == 'COCINA1'):
        #El usuario ingreso COCINA1
        ubicacion2 = input("Ingrese el estado de la COCINA 2 ")# el usuario indica la si la olla arrocera se encuentra Calentando o Cocinando (0/1) en la ubicación indicada.
        ubicacion3 = input("Ingrese el estado de la COCINA 3 ")# el usuario indica la si la olla arrocera se encuentra Calentando o Cocinando (0/1) en la ubicación indicada.
        print("Objetivo Deseado:" + str(estadoObjetivo)) #Se muestran los resultados deseados
    
        print("La Olla Arrocera se encuentra en la COCINA 1")# Se muestra la cocina en la que se encuentra la olla Arrocera

        if(estado == '1'):
            #La Olla Arrocera de la COCINA1 se encuentra calentando
            print("La Olla Arrocera se encuentra calentando")
            #La Olla Arrocera comenzará a cocinar
            estadoObjetivo['COCINA1'] ='0'
            costo += 1 #El costo aumentara cada que la Olla Arrocera cocine
            print("La Olla Arrocera esta cocinando en la COCINA 1")
            print("El costo actual es: " +str(costo)) #Muestra el costo actual 
                
            if(ubicacion2 == '1'):
                #si la Olla Arrocera de la COCINA2 se encuentra calentando
                print("La Olla Arrocera de la COCINA 2 se encuentra calentando")
                print("La Olla Arrocera es movida a la COCINA 2") 
                costo += 1 #Incrementa el costo por mover la Olla Arrocera
                print("El costo actual es: " +str(costo)) #Muestra el costo actual
                #La Olla Arrocera Cocinará
                estadoObjetivo['COCINA2'] ='0'
                costo += 1 #El costo aumentará cada que la Olla Arrocera cocine
                print("La olla Arrocera está cocinando en la COCINA 2 ")
                print("El costo actual es: "  +str(costo)) #Muestra el costo actual 
            else:
                #La Olla Arrocera se encuentra Cocinando
                print("La Olla Arrocera de la COCINA 2 se encuentra cocinando")
                print("No se realiza ninguna acción. El costo actual es: "  +str(costo))
            if(ubicacion3 == '1'):
                #si la Olla Arrocera de la COCINA3 se encuentra calentando
                print("La Olla Arrocera de la COCINA 3 se encuentra calentando")
                print("La Olla Arrocera es movida a la COCINA 3") 
                costo += 1 #Incrementa el costo por mover la Olla Arrocera
                print("El costo actual es: " +str(costo)) #Muestra el costo actual
                #La Olla Arrocera cocinará
                estadoObjetivo['COCINA3'] ='0'
                costo += 1 #El costo aumentará cada que la Olla Arrocera cocine
                print("La Olla Arrocera está cocinando en la COCINA 3")
                print("El costo actual es: "  +str(costo)) #Muestra el costo actual 
            else:
                #La Olla Arrocera se encuentra cocinando
                print("La Olla Arrocera de la COCINA 3 se encuentra cocinando")
                print("No se realiza ninguna acción. El costo actual es: "  +str(costo))
                
        elif (estado == '0'):
            print("La Olla Arrocera de la COCINA1 se encuentra cocinando")
            if(ubicacion2 == '1'):
                #Si la Olla Arrocera de la COCINA2 se encuentra calentando
                print("La Olla Arrocera de la COCINA2 se encuentra calentando")
                print("La Olla Arrocera es movido a la COCINA 2") 
                costo += 1 #Incrementa el costo por mover la Olla Arrocera
                print("El costo actual es: " +str(costo)) #Muestra el costo actual
                #La Olla Arrocera cocinará
                estadoObjetivo['COCINA2'] ='0'
                costo += 1 #El costo aumentará cada que la Olla Arrocera cocine
                print("La Olla Arrocera esta cocinando en la COCINA 2 ")
                print("El costo actual es: "  +str(costo)) #Muestra el costo actual 
            else:
                #La Olla Arrocera se encuentra cocinando
                print("La Olla Arrocera de la COCINA 2 se encuentra cocinando")
                print("No se realiza ninguna acción. El costo actual es: "  +str(costo))

            if(ubicacion3 == '1'):
                #si la Olla Arrocera de la COCINA3 se encuentra calentando
                print("La Olla Arrocera de la COCINA 3 se encuentra calentando")
                print("La Olla Arrocera es movida a la COCINA 3") 
                costo += 1 #Incrementa el costo por mover la Olla Arrrocera
                print("El costo actual es: " +str(costo)) #Muestra el costo actual
                #la Olla Arrocera cocinará
                estadoObjetivo['COCINA3'] ='0'
                costo += 1 #El costo aumentará cada que la Olla Arrocera cocine
                print("La Olla Arrocera esta cocinando en la COCINA 3")
                print("El costo actual es: "  +str(costo)) #Muestra el costo actual 
            else:
                #La Olla Arrocera se encuentra cocinando
                print("La Olla Arrocera de la COCINA 3 se encuentra cocinando")
                print("No se realiza ninguna acción. El costo actual es: "  +str(costo))

        else:      
            print("El estado insertado no tiene validez")
        
         elif (ubicacion  == 'COCINA2'):
        #El usuario ingreso a la COCINA2
        ubicacion2 = input("Ingrese el estado de la COCINA 1 ")# el usuario indica la si la Olla Arrocera se encuentra cocinando o Calentando (0/1) en la ubicación indicada.
        ubicacion3 = input("Ingrese el estado de la COCINA 3 ")# el usuario indica la si la Olla Arrocera se encuentra cocinando o Calentando (0/1) en la ubicación indicada.
        print("Objetivo Deseado:" + str(estadoObjetivo)) #Se muestran los resultados deseados
        
        print("La Olla Arrocera se encuentra en la COCINA 2")# Se muestra la cocina en la que se encuentra la olla Arrocera

        if(estado == '1'):
            #la Olla Arrocera de la COCINA2 se encuentra calentando
            print("La Olla Arrocera se encuentra calentando")
            #La Olla Arrocera cocinará
            estadoObjetivo['COCINA2'] ='0'
            costo += 1 #El costo incrementará cada que la Olla Arrocera este cocinando
            print("La Olla Arrocera esta cocinando en la COCINA 2")
            print("El costo actual es: " +str(costo)) #Muestra el costo actual 

            if(ubicacion2 == '1'):
                #si la Olla Arrocera de la COCINA1 se encuentra calentando
                print("La Olla Arrocera de la COCINA 1 se encuentra calentando")
                print("La Olla Arrocera es movida a la COCINA 1") 
                costo += 1 #Incrementa el costo por mover la Olla Arrocera
                print("El costo actual es: " +str(costo)) #Muestra el costo actual
                #La Olla Arrocera cocinará
                estadoObjetivo['COCINA1'] ='0'
                costo += 1 #El costo aumentará cada que la Olla Arrocera cocine
                print("La Olla Arrocera está cocinando en la COCINA 1 ")
                print("El costo actual es: "  +str(costo)) #Muestra el costo actual 
            
            else:
                #La Olla Arrocera se encuentra cocinando
                print("La Olla Arrocera de la COCINA 1 se encuentra cocinando")
                print("No se realiza ninguna acción. El costo actual es: "  +str(costo))
              
            if(ubicacion3 == '1'):
                #Si la Olla Arrocera de la COCINA3 se encuentra calentando
                print("La Olla Arrocera de la COCINA 3 se encuentra calentando")
                print("La Olla Arrocera  es movido a la COCINA 3") 
                costo += 1 #Incrementa el costo por mover la Olla Arrocera 
                print("El costo actual es: " +str(costo)) #Muestra el costo actual
                #La Olla Arrocera cocinará
                estadoObjetivo['COCINA3'] ='0'
                costo += 1 #El costo aumentará cada que La Olla Arrocera cocine
                print("La Olla Arrocera esta cocinando en la COCINA 3")
                print("El costo actual es: "  +str(costo)) #Muestra el costo actual 
            else:
                #La Olla Arrocera se encuentra cocinando
                print("La Olla Arrocera de la COCINA 3 se encuentra cocinando")
                print("No se realiza ninguna acción. El costo actual es: "  +str(costo))
                
        elif (estado == '0'):
            print("La Olla Arrocera de la COCINA 2 se encuentra cocinando")
            if(ubicacion2 == '1'):
                #Si la Olla Arrocera de la COCINA1 se encuentra calentando
                print("La Olla Arrocera de la COCINA 1 se encuentra calentando")
                print("La Olla Arrocera es movida a la COCINA 1") 
                costo += 1 #Incrementa el costo por mover la Olla Arrocera 
                print("El costo actual es: " +str(costo)) #Muestra el costo actual
                #La Olla Arrocera cocinará
                estadoObjetivo['COCINA1'] ='0'
                costo += 1 #El costo aumentara cada que la Olla Arrocera cocine
                print("La Olla Arrocera esta cocinando en la COCINA 1 ")
                print("El costo actual es: "  +str(costo)) #Muestra el costo actual 
            else:
                #La Olla Arrocera se encuentra cocinando
                print("La Olla Arrocera de la COCINA 1 se encuentra cocinando")
                print("No se realiza ninguna acción. El costo actual es: "  +str(costo))

            if(ubicacion3 == '1'):
                #si la Olla Arrocera de la COCINA3 se encuentra calentando
                print("La Olla Arrocera de la COCINA 3 se encuentra calentando")
                print("La Olla Arrocera es movido a la COCINA 3") 
                costo += 1 #Incrementa el costo por mover la Olla Arrocera.
                print("El costo actual es: " +str(costo)) #Muestra el costo actual
                #La Olla Arrocera cocinará
                estadoObjetivo['COCINA3'] ='0'
                costo += 1 #El costo aumentara cada que la Olla Arrocera cocine
                print("La Olla Arrocera esta cocinando en la COCINA 3")
                print("El costo actual es: "  +str(costo)) #Muestra el costo actual 
            else:
                #La Olla Arrocera se encuentra cocinando
                print("La Olla Arrocera de la COCINA 3 se encuentra cocinando")
                print("No se realiza ninguna acción. El costo actual es: "  +str(costo))

        else:      
            print("El estado insertado no tiene validez")
        
        elif (ubicacion  == 'COCINA3'):
        #El usuario ingreso COCINA3
        ubicacion2 = input("Ingrese el estado de la COCINA 1 ")# el usuario indica si la Olla Arrocera se encuentra Encendido o Apagado (0/1) en la ubicación indicada.
        ubicacion3 = input("Ingrese el estado de la COCINA 2 ")# el usuario indica si la Olla Arrocera se encuentra Encendido o Apagado (0/1) en la ubicación indicada.
        print("Objetivo Deseado:" + str(estadoObjetivo)) #Se muestran los resultados deseados
        
        print("La Olla Arrocera se encuentra en la COCINA 3")# Se muestra la cocina en la que se encuentra la Olla Arrocera
        
        if(estado == '1'):
            #La Olla Arrocera de la COCINA3 se encuentra calentando
            print("La Olla Arrocera se encuentra calentando")
            #La Olla Arrocera cocinará
            estadoObjetivo['COCINA3'] ='0'
            costo += 1 #El costo incrementará cada que la Olla Arrrocera cocine
            print("La Olla Arrocera esta cocinando en la COCINA 3")
            print("El costo actual es: " +str(costo)) #Muestra el costo actual 
          
            if(ubicacion2 == '1'):
                #Si la Olla Arrocera de la COCINA1 se encuentra calentando
                print("La Olla Arrocera de la COCINA 1 se encuentra calentando")
                print("La Olla Arrocera es movida a la COCINA 1") 
                costo += 1 #Incrementa el costo por mover la Olla Arrocera
                print("El costo actual es: " +str(costo)) #Muestra el costo actual
                #La Olla Arrocera se encendera
                estadoObjetivo['COCINA1'] ='0'
                costo += 1 #El costo incrementará cada que la Olla Arrocera se cocine
                print("La Olla Arrocera esta cocinando en la COCINA 1 ")
                print("El costo actual es: "  +str(costo)) #Muestra el costo actual 
            else:
                #La Olla Arrocera se encuentra cocinando
                print("La Olla Arrocera de la COCINA 1 se encuentra cocinando")
                print("No se realiza ninguna acción. El costo actual es: "  +str(costo))
              
            if(ubicacion3 == '1'):
                #si la Olla Arrocera de la COCINA2 se encuentra calentando
                print("La Olla Arrocera de la COCINA 2 se encuentra calentando")
                print("La Olla Arrocera es movida a la COCINA 2") 
                costo += 1 #Incrementa el costo por mover la Olla Arrocera
                print("El costo actual es: " +str(costo)) #Muestra el costo actual
                #La Olla Arrocera cocinará
                estadoObjetivo['COCINA2'] ='0'
                costo += 1 #El costo aumentara cada que la olla Arrocera cocine
                print("La Olla Arrocera esta cocinando en la COCINA 2 ")
                print("El costo actual es: "  +str(costo)) #Muestra el costo actual 
            else:
                #La Olla Arrocera se encuentra cocinando
                print("La Olla Arrocera de la COCINA 2 se encuentra cocinando")
                print("No se realiza ninguna acción. El costo actual es: "  +str(costo))
                
        elif (estado == '0'):
            print("La Olla Arrocera de la COCINA 3 se encuentra cocinando")
            if(ubicacion2 == '1'):
                #si la Olla Arrocera de la COCINA1 se encuentra calentando
                print("La Olla Arrocera de la COCINA 1 se encuentra calentando")
                print("La Olla Arrocera es movida a la COCINA 1") 
                costo += 1 #Incrementa el costo por mover La Olla Arrocera
                print("El costo actual es: " +str(costo)) #Muestra el costo actual
                #La Olla Arrocera cocinará
                estadoObjetivo['COCINA1'] ='0'
                costo += 1 #El costo incrementará cada que la Olla Arrocera cocine
                print("La Olla Arrocera esta cocinando en la COCINA 1 ")
                print("El costo actual es: "  +str(costo)) #Muestra el costo actual 
            else:
                #La Olla Arrocera se encuentra cocinando
                print("La Olla Arrocera de la COCINA 1 se encuentra cocinando")
                print("No se realiza ninguna acción. El costo actual es: "  +str(costo))

            if(ubicacion3 == '1'):
                #si la Olla Arrocera de la COCINA3 se encuentra calentando
                print("La Olla Arrocera de la COCINA 3 se encuentra calentando")
                print("La Olla Arrocera es movida a la COCINA 3") 
                costo += 1 #Incrementa el costo por mover la Olla Arrocera
                print("El costo actual es: " +str(costo)) #Muestra el costo actual
                #La Olla Arrocera cocinará
                estadoObjetivo['COCINA3'] ='0'
                costo += 1 #El costo incrementará cada que la Olla Arrocera se cocine
                print("La Olla Arrocera esta cocinando en la COCINA 3")
                print("El costo actual es: "  +str(costo)) #Muestra el costo actual 
            else:
                #La Olla Arrocera se encuentra cocinando
                print("La Olla Arrocera de la COCINA 3 se encuentra cocinando")
                print("No se realiza ninguna acción. El costo actual es: "  +str(costo))

        else:      
            print("El estado insertado no tiene validez")
             
    else:
        print("Ubicación desconocida") 
        
    #Todo Cocinando
    print("Estado Objetivo: " + str(estadoObjetivo))
    print("Medición del desempeño " +str(costo))
        

Olla_Arrocera()
